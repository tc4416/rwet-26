# %%
5+6
# Out:
# 11

# %%
x = 5
20 +x
# Out:
# 25

# %% [markdown]
# # expression and strings!

# %%
(5+3)*8
# Out:
# 64

# %% [markdown]
# # expression of inequality

# %%
2>5
# Out:
# False

# %%
(17 + 2)*4 <(22*5)/3
# Out:
# False

# %%
17>=17
# Out:
# True

# %% [markdown]
# # variable!

# %%
horatio = ( 8 * 5) + 2

# %%
horatio
# Out:
# 42

# %%
horatio * horatio
# Out:
# 1764

# %%
x = 9.4

# %%
horatio + 9.4
# Out:
# 51.4

# %%
x = 10

# %%
horatio * x
# Out:
# 420

# %% [markdown]
# # types

# %%
type(6)
# Out:
# int

# %%
type("hello")
# Out:
# str

# %%
type(17.8)
# Out:
# float

# %%
type(100+1)
# Out:
# int

# %%
type(5/6)
# Out:
# float

# %%
type(15>4)
# Out:
# bool

# %% [markdown]
# # strings

# %%
"hello there how are you"
# Out:
# 'hello there how are you'

# %%
type("hello")
# Out:
# str

# %%
"foo" in "buffoon" #check if its within
# Out:
# True

# %%
beef = "pigeon is there"

# %%
type(beef)
# Out:
# str

# %%
len(beef)
# Out:
# 15

# %%
"is" in beef
# Out:
# True

# %%
beef.capitalize
# Out:
# <function str.capitalize()>

# %%
beef
# Out:
# 'pigeon is there'

# %%
beef.capitalize?
# Out:
# Signature: beef.capitalize()
# Docstring:
# Return a capitalized version of the string.
#
# More specifically, make the first character have upper case and the rest lower
# case.
# Type:      builtin_function_or_method

# %%
beef.capitalize()
# Out:
# 'Pigeon is there'

# %% [markdown]
# # escape characters

# %%
story = "And then the mayor said, \"That's a great idea, yealh!\" and I was happy."

# %%
story
# Out:
# 'And then the mayor said, "That\'s a great idea, yealh!" and I was happy.'

# %%
print(story)
# Out:
# And then the mayor said, "That's a great idea, yealh!" and I was happy.

# %% [markdown]
# # other escape character!

# %%
poem = "\n this is a new line"
poem
print(poem)
# Out:
#  this is a new line

# %%
poem = "i never saw a purple cow \nand never hole to see one \nbut rom the milk we're getting now \nthere certainly must be one"
print(poem)
# Out:
# i never saw a purple cow
# and never hole to see one
# but rom the milk we're getting now
# there certainly must be one

# %%
tutorial ="use the backlash character \\ to make an escape character,"
print(tutorial)
# Out:
# use the backlash character \ to make an escape character,

# %%
blah = "here are two backlash: \\\\"
print(blah)
# Out:
# here are two backlash: \\

# %% [markdown]
# ### note: r" mean don't interprete any escapr character

# %%
blah = r"here is a backlash: \yay!"
print(blah)
# Out:
# here is a backlash: \yay!

# %% [markdown]
# ### triple quote(""") means the whole paragraph get evaluate together

# %%
poem = """i never saw a purple cow
and never hope to see one"""
print(poem)
# Out:
# i never saw a purple cow
# and never hope to see one

# %%
poem
# Out:
# 'i never saw a purple cow\nand never hope to see one'

# %% [markdown]
# ### when there is an backslash at the end of line, it tell python the end of line is not real

# %% [markdown]
# ## string methods and function

# %%
roastbeef = "suppose there is a pigeon, suppose there is"

# %%
len(roastbeef)
# Out:
# 43

# %%
"pigeon" in roastbeef
# Out:
# True

# %%
roastbeef.capitalize()
# Out:
# 'Suppose there is a pigeon, suppose there is'

# %%
roastbeef_book = roastbeef.title()
roastbeef_book
# Out:
# 'Suppose There Is A Pigeon, Suppose There Is'

# %%
roastbeef.upper()
# Out:
# 'SUPPOSE THERE IS A PIGEON, SUPPOSE THERE IS'

# %%
roastbeef.lower()
# Out:
# 'suppose there is a pigeon, suppose there is'

# %%
tricky = "This is not that.Thanks"

# %%
roastbeef
# Out:
# 'suppose there is a pigeon, suppose there is'

# %%
"thanks" in tricky
# Out:
# False

# %%
"thanks" in tricky.lower()
# Out:
# True

# %% [markdown]
# # index and sllicing

# %%
roastbeef[5]
# Out:
# 's'

# %%
"cheessball"[4]
# Out:
# 's'

# %%
roastbeef.upper()[3].lower()
# Out:
# 'p'

# %%
rb_up= roastbeef.upper()
rb_substr= rb_up[3]
rb_substr_lw = rb_substr.lower()
rb_substr_lw
# Out:
# 'p'

# %%
roastbeef[-1]
# Out:
# 's'

# %%
roastbeef[-5]
# Out:
# 'r'

# %%
# fake javascript roastbeef.charAt(roastbeef.length-1)

# %%
#slicing

# %%
roastbeef[4:7]
# Out:
# 'ose'

# %%
roastbeef[:10]
# Out:
# 'suppose th'

# %%
roastbeef[-5:-2]
# Out:
# 're '

# %%
roastbeef[-5:]
# Out:
# 're is'

# %%
roastbeef
# Out:
# 'suppose there is a pigeon, suppose there is'

# %%
x = 8
roastbeef[x:x+5]
# Out:
# 'there'

# %% [markdown]
# # concatenation

# %%
"hello" + "there"
# Out:
# 'hellothere'

# %%
"Getrude Stein wrote : \""+ roastbeef + ".\""
# Out:
# 'Getrude Stein wrote : "suppose there is a pigeon, suppose there is."'

# %%
"hello" + str(10)
# Out:
# 'hello10'

# %% [markdown]
# ## list, indexing, slicing

# %%
[5, 10, 15, 20, 25]
# Out:
# [5, 10, 15, 20, 25]

# %%
grumpy = [5, 10 , 15, 20, 25]

# %%
grumpy
# Out:
# [5, 10, 15, 20, 25]

# %%
type(grumpy)
# Out:
# list

# %%
grumpy[0]
# Out:
# 5

# %%
grumpy[-1]
# Out:
# 25

# %%
grumpy[-2]
# Out:
# 20

# %%
grumpy[1:4]
# Out:
# [10, 15, 20]

# %% [markdown]
# ## list comprehensions
#
# input -> filtering/modification -> output
#
# [pred_expr for tmp_var in list_expr if filter_expr]

# %%
[item*2 for item in grumpy if item>10]
# Out:
# [30, 40, 50]

# %%
grumpy
# Out:
# [5, 10, 15, 20, 25]

# %% [markdown]
# #fake javascript
# let inoutVals = [5.10. 15. 20. 25];
# let output = [];
# for (let i = 0; i< inputVals.length; i++){
# if(inputVals[i]>10){
#     outputVals.push(inputVsla[i]*2)
#     }

# %%
poem = """
Two roads diverged in a yellow wood,
And sorry I could not travel both
And be one traveler, long I stood
And looked down one as far as I could
To where it bent in the undergrowth;

Then took the other, as just as fair,
And having perhaps the better claim,
Because it was grassy and wanted wear;
Though as for that the passing there
Had worn them really about the same,

And both that morning equally lay
In leaves no step had trodden black.
Oh, I kept the first for another day!
Yet knowing how way leads on to way,
I doubted if I should ever come back.

I shall be telling this with a sigh
Somewhere ages and ages hence:
Two roads diverged in a wood, and I––
I took the one less traveled by,
And that has made all the difference.
"""

# %%
poem
# Out:
# '\nTwo roads diverged in a yellow wood,\nAnd sorry I could not travel both\nAnd be one traveler, long I stood\nAnd looked down one as far as I could\nTo where it bent in the undergrowth;\n\nThen took the other, as just as fair,\nAnd having perhaps the better claim,\nBecause it was grassy and wanted wear;\nThough as for that the passing there\nHad worn them really about the same,\n\nAnd both that morning equally lay\nIn leaves no step had trodden black.\nOh, I kept the first for another day!\nYet knowing how way leads on to way,\nI doubted if I should ever come back.\n\nI shall be telling this with a sigh\nSomewhere ages and ages hence:\nTwo roads diverged in a wood, and I––\nI took the one less traveled by,\nAnd that has made all the difference.\n'

# %%
lines = poem.split("\n")

# %%
lines
# Out:
# ['',
#  'Two roads diverged in a yellow wood,',
#  'And sorry I could not travel both',
#  'And be one traveler, long I stood',
#  'And looked down one as far as I could',
#  'To where it bent in the undergrowth;',
#  '',
#  'Then took the other, as just as fair,',
#  'And having perhaps the better claim,',
#  'Because it was grassy and wanted wear;',
#  'Though as for that the passing there',
#  'Had worn them really about the same,',
#  '',
#  'And both that morning equally lay',
#  'In leaves no step had trodden black.',
#  'Oh, I kept the first for another day!',
#  'Yet knowing how way leads on to way,',
#  'I doubted if I should ever come back.',
#  '',
#  'I shall be telling this with a sigh',
#  'Somewhere ages and ages hence:',
#  'Two roads diverged in a wood, and I––',
#  'I took the one less traveled by,',
#  'And that has made all the difference.',
#  '']

# %%
[item.upper() for item in lines ]
# Out:
# ['',
#  'TWO ROADS DIVERGED IN A YELLOW WOOD,',
#  'AND SORRY I COULD NOT TRAVEL BOTH',
#  'AND BE ONE TRAVELER, LONG I STOOD',
#  'AND LOOKED DOWN ONE AS FAR AS I COULD',
#  'TO WHERE IT BENT IN THE UNDERGROWTH;',
#  '',
#  'THEN TOOK THE OTHER, AS JUST AS FAIR,',
#  'AND HAVING PERHAPS THE BETTER CLAIM,',
#  'BECAUSE IT WAS GRASSY AND WANTED WEAR;',
#  'THOUGH AS FOR THAT THE PASSING THERE',
#  'HAD WORN THEM REALLY ABOUT THE SAME,',
#  '',
#  'AND BOTH THAT MORNING EQUALLY LAY',
#  'IN LEAVES NO STEP HAD TRODDEN BLACK.',
#  'OH, I KEPT THE FIRST FOR ANOTHER DAY!',
#  'YET KNOWING HOW WAY LEADS ON TO WAY,',
#  'I DOUBTED IF I SHOULD EVER COME BACK.',
#  '',
#  'I SHALL BE TELLING THIS WITH A SIGH',
#  'SOMEWHERE AGES AND AGES HENCE:',
#  'TWO ROADS DIVERGED IN A WOOD, AND I––',
#  'I TOOK THE ONE LESS TRAVELED BY,',
#  'AND THAT HAS MADE ALL THE DIFFERENCE.',
#  '']

# %%
[item.upper() + "STOP" for item in lines if len(item)>0]
# Out:
# ['TWO ROADS DIVERGED IN A YELLOW WOOD,STOP',
#  'AND SORRY I COULD NOT TRAVEL BOTHSTOP',
#  'AND BE ONE TRAVELER, LONG I STOODSTOP',
#  'AND LOOKED DOWN ONE AS FAR AS I COULDSTOP',
#  'TO WHERE IT BENT IN THE UNDERGROWTH;STOP',
#  'THEN TOOK THE OTHER, AS JUST AS FAIR,STOP',
#  'AND HAVING PERHAPS THE BETTER CLAIM,STOP',
#  'BECAUSE IT WAS GRASSY AND WANTED WEAR;STOP',
#  'THOUGH AS FOR THAT THE PASSING THERESTOP',
#  'HAD WORN THEM REALLY ABOUT THE SAME,STOP',
#  'AND BOTH THAT MORNING EQUALLY LAYSTOP',
#  'IN LEAVES NO STEP HAD TRODDEN BLACK.STOP',
#  'OH, I KEPT THE FIRST FOR ANOTHER DAY!STOP',
#  'YET KNOWING HOW WAY LEADS ON TO WAY,STOP',
#  'I DOUBTED IF I SHOULD EVER COME BACK.STOP',
#  'I SHALL BE TELLING THIS WITH A SIGHSTOP',
#  'SOMEWHERE AGES AND AGES HENCE:STOP',
#  'TWO ROADS DIVERGED IN A WOOD, AND I––STOP',
#  'I TOOK THE ONE LESS TRAVELED BY,STOP',
#  'AND THAT HAS MADE ALL THE DIFFERENCE.STOP']

# %%
[item.strip() for item in lines if len(item)>0]
# Out:
# ['Two roads diverged in a yellow wood,',
#  'And sorry I could not travel both',
#  'And be one traveler, long I stood',
#  'And looked down one as far as I could',
#  'To where it bent in the undergrowth;',
#  'Then took the other, as just as fair,',
#  'And having perhaps the better claim,',
#  'Because it was grassy and wanted wear;',
#  'Though as for that the passing there',
#  'Had worn them really about the same,',
#  'And both that morning equally lay',
#  'In leaves no step had trodden black.',
#  'Oh, I kept the first for another day!',
#  'Yet knowing how way leads on to way,',
#  'I doubted if I should ever come back.',
#  'I shall be telling this with a sigh',
#  'Somewhere ages and ages hence:',
#  'Two roads diverged in a wood, and I––',
#  'I took the one less traveled by,',
#  'And that has made all the difference.']

# %%
clean_lines = [item.strip() for item in lines if len(item)>0]

# %%
[ item for item in clean_lines if "e" not in lines]
# Out:
# ['Two roads diverged in a yellow wood,',
#  'And sorry I could not travel both',
#  'And be one traveler, long I stood',
#  'And looked down one as far as I could',
#  'To where it bent in the undergrowth;',
#  'Then took the other, as just as fair,',
#  'And having perhaps the better claim,',
#  'Because it was grassy and wanted wear;',
#  'Though as for that the passing there',
#  'Had worn them really about the same,',
#  'And both that morning equally lay',
#  'In leaves no step had trodden black.',
#  'Oh, I kept the first for another day!',
#  'Yet knowing how way leads on to way,',
#  'I doubted if I should ever come back.',
#  'I shall be telling this with a sigh',
#  'Somewhere ages and ages hence:',
#  'Two roads diverged in a wood, and I––',
#  'I took the one less traveled by,',
#  'And that has made all the difference.']

# %%
[item for item in clean_lines if item[0] == "I"]
# Out:
# ['In leaves no step had trodden black.',
#  'I doubted if I should ever come back.',
#  'I shall be telling this with a sigh',
#  'I took the one less traveled by,']

# %%
["💕" + item.lower() + "😻" for item in clean_lines]
# Out:
# ['💕two roads diverged in a yellow wood,😻',
#  '💕and sorry i could not travel both😻',
#  '💕and be one traveler, long i stood😻',
#  '💕and looked down one as far as i could😻',
#  '💕to where it bent in the undergrowth;😻',
#  '💕then took the other, as just as fair,😻',
#  '💕and having perhaps the better claim,😻',
#  '💕because it was grassy and wanted wear;😻',
#  '💕though as for that the passing there😻',
#  '💕had worn them really about the same,😻',
#  '💕and both that morning equally lay😻',
#  '💕in leaves no step had trodden black.😻',
#  '💕oh, i kept the first for another day!😻',
#  '💕yet knowing how way leads on to way,😻',
#  '💕i doubted if i should ever come back.😻',
#  '💕i shall be telling this with a sigh😻',
#  '💕somewhere ages and ages hence:😻',
#  '💕two roads diverged in a wood, and i––😻',
#  '💕i took the one less traveled by,😻',
#  '💕and that has made all the difference.😻']

# %%
["💕" + item.replace(";", "🦄") + "😻" for item in clean_lines]
# Out:
# ['💕Two roads diverged in a yellow wood,😻',
#  '💕And sorry I could not travel both😻',
#  '💕And be one traveler, long I stood😻',
#  '💕And looked down one as far as I could😻',
#  '💕To where it bent in the undergrowth🦄😻',
#  '💕Then took the other, as just as fair,😻',
#  '💕And having perhaps the better claim,😻',
#  '💕Because it was grassy and wanted wear🦄😻',
#  '💕Though as for that the passing there😻',
#  '💕Had worn them really about the same,😻',
#  '💕And both that morning equally lay😻',
#  '💕In leaves no step had trodden black.😻',
#  '💕Oh, I kept the first for another day!😻',
#  '💕Yet knowing how way leads on to way,😻',
#  '💕I doubted if I should ever come back.😻',
#  '💕I shall be telling this with a sigh😻',
#  '💕Somewhere ages and ages hence:😻',
#  '💕Two roads diverged in a wood, and I––😻',
#  '💕I took the one less traveled by,😻',
#  '💕And that has made all the difference.😻']

# %%
short_road = [item[:5]+item[-5:] for item  in clean_lines]

# %%
print(short_road)
# Out:
# ['Two rwood,', 'And s both', 'And bstood', 'And lcould', 'To whowth;', 'Then fair,', 'And hlaim,', 'Becauwear;', 'Thougthere', 'Had wsame,', 'And by lay', 'In lelack.', 'Oh, I day!', 'Yet k way,', 'I douback.', 'I sha sigh', 'Somewence:', 'Two rd I––', 'I tood by,', 'And tence.']

# %%
glue="\n"
finished_poem = glue.join(short_road) # or "\n".join(short_road)
print(finished_poem)
# Out:
# Two rwood,
# And s both
# And bstood
# And lcould
# To whowth;
# Then fair,
# And hlaim,
# Becauwear;
# Thougthere
# Had wsame,
# And by lay
# In lelack.
# Oh, I day!
# Yet k way,
# I douback.
# I sha sigh
# Somewence:
# Two rd I––
# I tood by,
# And tence.

# %%
glue="🦄"
finished_poem = glue.join(short_road)
print(finished_poem)
# Out:
# Two rwood,🦄And s both🦄And bstood🦄And lcould🦄To whowth;🦄Then fair,🦄And hlaim,🦄Becauwear;🦄Thougthere🦄Had wsame,🦄And by lay🦄In lelack.🦄Oh, I day!🦄Yet k way,🦄I douback.🦄I sha sigh🦄Somewence:🦄Two rd I––🦄I tood by,🦄And tence.

# %% [markdown]
# # changing lists

# %%
clean_lines.append("and I was happy about it.")

# %%
clean_lines
# Out:
# ['Two roads diverged in a yellow wood,',
#  'And sorry I could not travel both',
#  'And be one traveler, long I stood',
#  'And looked down one as far as I could',
#  'To where it bent in the undergrowth;',
#  'Then took the other, as just as fair,',
#  'And having perhaps the better claim,',
#  'Because it was grassy and wanted wear;',
#  'Though as for that the passing there',
#  'Had worn them really about the same,',
#  'And both that morning equally lay',
#  'In leaves no step had trodden black.',
#  'Oh, I kept the first for another day!',
#  'Yet knowing how way leads on to way,',
#  'I doubted if I should ever come back.',
#  'I shall be telling this with a sigh',
#  'Somewhere ages and ages hence:',
#  'Two roads diverged in a wood, and I––',
#  'I took the one less traveled by,',
#  'And that has made all the difference.',
#  'and I was happy about it.',
#  'and I was happy about it.',
#  'and I was happy about it.',
#  'and I was happy about it.']

# %%
import random

# %%
random.choice(clean_lines)
# Out:
# 'and I was happy about it.'

# %%
random.sample(clean_lines, 4)
# Out:
# ['To where it bent in the undergrowth;',
#  'And that has made all the difference.',
#  'Two roads diverged in a yellow wood,',
#  'and I was happy about it.']

# %%
print("\n".join(random.sample(clean_lines,3)))
# Out:
# Yet knowing how way leads on to way,
# Two roads diverged in a wood, and I––
# And that has made all the difference.

# %%
rando,.sample(clean_lines

# %% [markdown]
# # for loops

# %%
for item in clean_lines:
    mew_thing = item.upper()
    print(item.upper())
print("done")
# Out:
# TWO ROADS DIVERGED IN A YELLOW WOOD,
# AND SORRY I COULD NOT TRAVEL BOTH
# AND BE ONE TRAVELER, LONG I STOOD
# AND LOOKED DOWN ONE AS FAR AS I COULD
# TO WHERE IT BENT IN THE UNDERGROWTH;
# THEN TOOK THE OTHER, AS JUST AS FAIR,
# AND HAVING PERHAPS THE BETTER CLAIM,
# BECAUSE IT WAS GRASSY AND WANTED WEAR;
# THOUGH AS FOR THAT THE PASSING THERE
# HAD WORN THEM REALLY ABOUT THE SAME,
# AND BOTH THAT MORNING EQUALLY LAY
# IN LEAVES NO STEP HAD TRODDEN BLACK.
# OH, I KEPT THE FIRST FOR ANOTHER DAY!
# YET KNOWING HOW WAY LEADS ON TO WAY,
# I DOUBTED IF I SHOULD EVER COME BACK.
# I SHALL BE TELLING THIS WITH A SIGH
# SOMEWHERE AGES AND AGES HENCE:
# TWO ROADS DIVERGED IN A WOOD, AND I––
# I TOOK THE ONE LESS TRAVELED BY,
# AND THAT HAS MADE ALL THE DIFFERENCE.
# AND I WAS HAPPY ABOUT IT.
# AND I WAS HAPPY ABOUT IT.
# AND I WAS HAPPY ABOUT IT.
# AND I WAS HAPPY ABOUT IT.
# done

# %%
for item in range(10):
    print(random.choice(clean_lines))
# Out:
# Because it was grassy and wanted wear;
# Two roads diverged in a yellow wood,
# And both that morning equally lay
# And that has made all the difference.
# Two roads diverged in a wood, and I––
# and I was happy about it.
# And both that morning equally lay
# I shall be telling this with a sigh
# Somewhere ages and ages hence:
# and I was happy about it.

# %%
clean_lines.pop(4)
# Out:
# 'To where it bent in the undergrowth;'

# %%
my_copy=clean_lines[:]

# %%
clean_lines[0:4] + clean_lines[5:]
# Out:
# ['Two roads diverged in a yellow wood,',
#  'And sorry I could not travel both',
#  'And be one traveler, long I stood',
#  'And looked down one as far as I could',
#  'And having perhaps the better claim,',
#  'Because it was grassy and wanted wear;',
#  'Though as for that the passing there',
#  'Had worn them really about the same,',
#  'And both that morning equally lay',
#  'In leaves no step had trodden black.',
#  'Oh, I kept the first for another day!',
#  'Yet knowing how way leads on to way,',
#  'I doubted if I should ever come back.',
#  'I shall be telling this with a sigh',
#  'Somewhere ages and ages hence:',
#  'Two roads diverged in a wood, and I––',
#  'I took the one less traveled by,',
#  'And that has made all the difference.',
#  'and I was happy about it.',
#  'and I was happy about it.',
#  'and I was happy about it.',
#  'and I was happy about it.']
